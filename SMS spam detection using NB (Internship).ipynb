# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

raw_df = pd.read_csv(
    "spam.csv",
    encoding="cp1252",
    engine="python"
)

# %%
raw_df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df = raw_df[['v1', 'v2']].copy()
df.columns = ['label', 'sms_message']

# %%
df['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.label.unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
#df.sms_message.unique()

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
df.head()
# Out:
#    label                                        sms_message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
df["label"]=df.label.map({"ham":0,"spam":1})

# %%
import pandas as pd

df = pd.read_csv(
    "spam.csv",
    encoding="cp1252",
    sep=",",
    engine="python"
)

# %%
df = df[['v1', 'v2']]
df.columns = ['label', 'sms_message']

# %%
df.label.unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
df.sms_message.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: sms_message, dtype: object

# %%
df["label"] = df.label.map({"ham": 0, "spam": 1})

# %%
df["label"].value_counts()
# Out:
# label
# 0    4825
# 1     747
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    label                                        sms_message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.model_selection import train_test_split

X_train_text, X_test_text, y_train, y_test = train_test_split(
    df['sms_message'],
    df['label'],
    test_size=0.2,
    random_state=42
)

# %%
len(X_train_text), len(X_test_text)
# Out:
# (4457, 1115)

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vector = CountVectorizer()

# %%
type(count_vector)
# Out:
# sklearn.feature_extraction.text.CountVectorizer

# %%
count_vector
# Out:
# CountVectorizer()

# %%
X_train = count_vector.fit_transform(X_train_text)

# %%
X_train.shape
# Out:
# (4457, 7735)

# %%
X_test = count_vector.transform(X_test_text)

# %%
X_test.shape
# Out:
# (1115, 7735)

# %%
count_vector.get_feature_names_out()
# Out:
# array(['00', '000', '000pes', ..., 'ûïharry', 'ûò', 'ûówell'],
#       shape=(7735,), dtype=object)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
naive_bayes=MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
type(nb_model)
# Out:
# sklearn.naive_bayes.MultinomialNB

# %%
predictions = nb_model.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.9838565022421525

# %%
predictions
# Out:
# array([0, 0, 1, ..., 0, 0, 1], shape=(1115,))

# %%
predlist=list(zip(predictions,y_test))

# %%
#predlist

# %%
#Evaluating the model

# %%
from sklearn.metrics import accuracy_score,precision_score

# %%
score=accuracy_score(y_test,predictions)

# %%
score
# Out:
# 0.9838565022421525

# %%
X_test_text.iloc[1089]
# Out:
# 'Win the newest åÒHarry Potter and the Order of the Phoenix (Book 5) reply HARRY, answer 5 questions - chance to be the first among readers!'

# %%
msg_vector = count_vector.transform([X_test_text.iloc[1087]])
nb_model.predict(msg_vector)
# Out:
# array([0])

# %%
nb_model.predict(count_vector.transform([X_test_text.iloc[1087]]))
# Out:
# array([0])

# %%
sms1=input("Enter the SMS message received")
predict_sms = nb_model.predict(count_vector.transform([sms1]))
print(predict_sms[0])
if(predict_sms[0]==0):
    print("Message is ham")
else:
    print("Message is spam")
# Out:
# Enter the SMS message received Hey! lets meet today.
# 0
# Message is ham

# %%
sms1=input("Enter the SMS message received")
predict_sms = nb_model.predict(count_vector.transform([sms1]))
print(predict_sms[0])
if(predict_sms[0]==0):
    print("Message is ham")
else:
    print("Message is spam")
# Out:
# Enter the SMS message received You've received prize money. Click to claim!
# 1
# Message is spam
